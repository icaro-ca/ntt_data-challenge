# %% [markdown]
# ## Create Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS covid_19;

# %% [markdown]
# ## Create Schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS covid_19.bronze;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS covid_19.silver;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS covid_19.gold;

# %% [markdown]
# ## Create Volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS covid_19.bronze.raw_data;
